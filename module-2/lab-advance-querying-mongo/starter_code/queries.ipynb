# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
import folium
import pymongo
from pymongo import MongoClient
import pandas as pd
client=MongoClient()
db=client.Datab

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
datab=db.Datab

list(datab.find({'name':{'$lt':'Babelgum'}}, {'name':1, '_id':0}))
# Out:
# [{'name': 'AdventNet'},
#  {'name': 'AddThis'},
#  {'name': 'AdaptiveBlue'},
#  {'name': 'AllPeers'},
#  {'name': 'AllofMP3'},
#  {'name': '37signals'},
#  {'name': 'Adobe Systems'},
#  {'name': 'Amazon'},
#  {'name': 'Alstrasoft'},
#  {'name': 'AOL'},
#  {'name': 'Aniboom'},
#  {'name': 'ActiveWorlds'},
#  {'name': 'Akamai Technologies'},
#  {'name': 'A9'},
#  {'name': 'Alibaba'},
#  {'name': 'Atom Entertainment'},
#  {'name': 'Adknowledge'},
#  {'name': 'BBE'},
#  {'name': 'Alloy'},
#  {'name': 'AdMob'},
#  {'name': 'AgentMatch'},
#  {'name': 'Attributor'},
#  {'name': '4INFO'},
#  {'name': 'Aviary'},
#  {'name': 'Avvo'},
#  {'name': 'Auctomatic'},
#  {'name': 'Airborne Mobile'},
#  {'name': 'Animoto'},
#  {'name': '3Jam'},
#  {'name': '23andMe'},
#  {'name': 'AdReady'},
#  {'name': 'Automattic'},
#  {'name': 'All-Scrap'},
#  {'name': 'Alipay'},
#  {'name': 'Alisoft'},
#  {'name': 'ActionThis'},
#  {'name': 'Akimbo'},
#  {'name': 'Adteractive'},
#  {'name': 'Apprema'},
# ...

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
list(datab.find({'number_of_employees':{'$gt': 5000}},{'number_of_employees':1, 'name':1, '_id': 0}).sort([('number_of_employees', -1)]).limit(20))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Safeway', 'number_of_employees': 186000},
#  {'name': 'Sony', 'number_of_employees': 180500},
#  {'name': 'LG', 'number_of_employees': 177000},
#  {'name': 'Boeing', 'number_of_employees': 160000},
#  {'name': 'Nokia', 'number_of_employees': 125000},
#  {'name': 'MItsubishi Electric', 'number_of_employees': 107000},
#  {'name': 'Comcast', 'number_of_employees': 100000},
#  {'name': 'Bertelsmann', 'number_of_employees': 100000},
#  {'name': 'MetaCarta', 'number_of_employees': 99999},
#  {'name': 'Microsoft', 'number_of_employees': 90000},
#  {'name': 'CSC', 'number_of_employees': 90000},
#  {'name': 'Intel', 'number_of_employees': 86300},
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
list(datab.find({'$and': [{'$or': [{'founded_year':{'$gt': 2000}}]}, {'$or': [{'founded_year':{'$lt': 2005}}]}]}, {'name':1, 'founded_year':1,'_id': 0}))
# Out:
# [{'name': 'Digg', 'founded_year': 2004},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'StumbleUpon', 'founded_year': 2002},
#  {'name': 'Gizmoz', 'founded_year': 2003},
#  {'name': 'Plaxo', 'founded_year': 2002},
#  {'name': 'Technorati', 'founded_year': 2002},
#  {'name': 'AddThis', 'founded_year': 2004},
#  {'name': 'Veoh', 'founded_year': 2004},
#  {'name': 'Meetup', 'founded_year': 2002},
#  {'name': 'SmugMug', 'founded_year': 2002},
#  {'name': 'Skype', 'founded_year': 2003},
#  {'name': 'Pando Networks', 'founded_year': 2004},
#  {'name': 'Ikan', 'founded_year': 2003},
#  {'name': 'delicious', 'founded_year': 2003},
#  {'name': 'Topix', 'founded_year': 2002},
#  {'name': 'Jobster', 'founded_year': 2004},
#  {'name': 'AllPeers', 'founded_year': 2004},
#  {'name': 'iContact', 'founded_year': 2003},
#  {'name': 'blinkx', 'founded_year': 2004},
#  {'name': 'Yelp', 'founded_year': 2004},
#  {'name': 'Coghead', 'founded_year': 2003},
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
list(datab.find({'$and': [{'ipo.valuation_amount':{'$gte': 100000}}, {'founded_year':{'$lt': 2010}}]}, {'name':1, 'ipo':1,'_id': 0}))
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}},
#  {'name': 'Yelp',
#   'ipo': {'valuation_amount': 1300000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 3,
#    'pub_day': 2,
#    'stock_symbol': 'NYSE:YELP'}},
#  {'name': 'LinkedIn',
#   'ipo': {'valuation_amount': 9310000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2011,
#    'pub_month': 7,
#    'pub_day': 20,
#    'stock_symbol': 'NYSE:LNKD'}},
#  {'name': 'Amazon',
#   'ipo': {'valuation_amount': 100000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 1997,
#    'pub_month': 5,
#    'pub_day': None,
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
list(datab.find({'$and': [{'number_of_employees':{'$lt': 1000}}, {'founded_year':{'$lt': 2005}}]}, {'name':1, 'number_of_employees':1,'_id': 0,'founded_year':1}).sort('number_of_employees',-1).limit(10))
# Out:
# [{'name': 'Infinera Corporation',
#   'number_of_employees': 974,
#   'founded_year': 2000},
#  {'name': 'Forrester Research',
#   'number_of_employees': 903,
#   'founded_year': 1983},
#  {'name': 'Yelp', 'number_of_employees': 800, 'founded_year': 2004},
#  {'name': 'MySpace', 'number_of_employees': 800, 'founded_year': 2003},
#  {'name': 'ZoomInfo', 'number_of_employees': 800, 'founded_year': 2000},
#  {'name': 'Mozilla', 'number_of_employees': 800, 'founded_year': 1998},
#  {'name': 'Buongiorno', 'number_of_employees': 800, 'founded_year': 1999},
#  {'name': 'Cvent', 'number_of_employees': 800, 'founded_year': 1999},
#  {'name': 'Wayfair', 'number_of_employees': 800, 'founded_year': 2002},
#  {'name': 'BitDefender', 'number_of_employees': 800, 'founded_year': 1996}]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
list(datab.find({'partners':{'$exists':False}}, {'name':1, '_id':0}))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(datab.find({'category_code':{'$exists':False}}, {'category_code':1,'name':1, '_id':0}))
# Out:
# []

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
list(datab.find({'$and':[{'number_of_employees':{'$gte': 100}},{'number_of_employees':{'$lt': 1000}} ]},{'number_of_employees':1, 'name':1, '_id': 0}))
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600},
#  {'name': 'AddThis', 'number_of_employees': 120},
#  {'name': 'OpenX', 'number_of_employees': 305},
#  {'name': 'LifeLock', 'number_of_employees': 644},
#  {'name': 'Jajah', 'number_of_employees': 110},
#  {'name': 'Livestream', 'number_of_employees': 120},
#  {'name': 'Ustream', 'number_of_employees': 250},
#  {'name': 'iContact', 'number_of_employees': 300},
#  {'name': 'Yelp', 'number_of_employees': 800},
#  {'name': 'Dailymotion', 'number_of_employees': 120},
#  {'name': 'RockYou', 'number_of_employees': 106},
#  {'name': 'Meebo', 'number_of_employees': 200},
#  {'name': 'Eventbrite', 'number_of_employees': 200},
#  {'name': 'Box', 'number_of_employees': 950},
#  {'name': 'Conduit', 'number_of_employees': 215},
#  {'name': 'Redfin', 'number_of_employees': 100},
#  {'name': 'oDesk', 'number_of_employees': 120},
#  {'name': 'Simply Hired', 'number_of_employees': 100},
#  {'name': 'PhotoBox', 'number_of_employees': 600},
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
list(datab.find({'ipo.valuation_amount':{'$gt':0}}, {'name':1,'ipo':1, '_id':0}).sort('ipo.valuation_amount',-1))
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Amazon',
#   'ipo': {'valuation_amount': 100000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 1997,
#    'pub_month': 5,
#    'pub_day': None,
#    'stock_symbol': 'NASDAQ:AMZN'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}},
#  {'name': 'Tencent',
#   'ipo': {'valuation_amount': 11000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2004,
#    'pub_month': 6,
#    'pub_day': 16,
#    'stock_symbol': 'HK:0700'}},
#  {'name': 'LinkedIn',
#   'ipo': {'valuation_amount': 9310000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2011,
#    'pub_month': 7,
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
list(datab.find({'number_of_employees':{'$gt': 5000}},{'number_of_employees':1, 'name':1, '_id': 0}).sort([('number_of_employees', -1)]).limit(10))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Safeway', 'number_of_employees': 186000},
#  {'name': 'Sony', 'number_of_employees': 180500},
#  {'name': 'LG', 'number_of_employees': 177000},
#  {'name': 'Boeing', 'number_of_employees': 160000},
#  {'name': 'Nokia', 'number_of_employees': 125000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(datab.find({'founded_month':{'$gt':6}}, {'name':1, 'founded_month':1,'_id':0}).limit(1000))
# Out:
# [{'name': 'Wetpaint', 'founded_month': 10},
#  {'name': 'Zoho', 'founded_month': 9},
#  {'name': 'Digg', 'founded_month': 10},
#  {'name': 'Omnidrive', 'founded_month': 11},
#  {'name': 'eBay', 'founded_month': 9},
#  {'name': 'Joost', 'founded_month': 10},
#  {'name': 'Plaxo', 'founded_month': 11},
#  {'name': 'Powerset', 'founded_month': 10},
#  {'name': 'Kyte', 'founded_month': 12},
#  {'name': 'Thoof', 'founded_month': 12},
#  {'name': 'Jingle Networks', 'founded_month': 9},
#  {'name': 'LifeLock', 'founded_month': 8},
#  {'name': 'Wesabe', 'founded_month': 12},
#  {'name': 'SmugMug', 'founded_month': 11},
#  {'name': 'Google', 'founded_month': 9},
#  {'name': 'Skype', 'founded_month': 8},
#  {'name': 'Pando Networks', 'founded_month': 7},
#  {'name': 'Ikan', 'founded_month': 12},
#  {'name': 'delicious', 'founded_month': 9},
#  {'name': 'AllPeers', 'founded_month': 8},
#  {'name': 'Wize', 'founded_month': 8},
#  {'name': 'SellABand', 'founded_month': 8},
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
list(datab.find({'deadpooled_year'-'founded_year':{'$gt':3}}, {'name':1, 'deadpooled_year':1,'_id':0}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-356-2f69d4e08fde> in <module>
# ----> 1 list(datab.find({'deadpooled_year'-'founded_year':{'$gt':3}}, {'name':1, 'deadpooled_year':1,'_id':0}))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
list(datab.find({'$and': [{'founded_year':{'$lt': 2000}},{'acquisitions.price_amount':{'$exists': True}}, {'acquisitions.price_amount':{'$gt': 10000}}]}, {'name':1, 'number_of_employees':1,'_id': 0}))
# Out:
# [{'name': 'Fox Interactive Media', 'number_of_employees': 0},
#  {'name': 'eBay', 'number_of_employees': 15000},
#  {'name': 'CBS', 'number_of_employees': None},
#  {'name': 'Viacom', 'number_of_employees': None},
#  {'name': 'Cisco', 'number_of_employees': 63000},
#  {'name': 'Yahoo!', 'number_of_employees': 13600},
#  {'name': 'Google', 'number_of_employees': 28000},
#  {'name': 'Intel', 'number_of_employees': 86300},
#  {'name': 'Ticketmaster', 'number_of_employees': 0},
#  {'name': 'Scripps Networks Interactive', 'number_of_employees': None},
#  {'name': 'NetSuite', 'number_of_employees': 1600},
#  {'name': 'Adobe Systems', 'number_of_employees': 7173},
#  {'name': 'Sony', 'number_of_employees': 180500},
#  {'name': 'Amazon', 'number_of_employees': None},
#  {'name': 'Qualcomm', 'number_of_employees': None},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'The Walt Disney Company', 'number_of_employees': 25000},
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
list(datab.find({'acquisitions.acquired_year':{'$gt':2015}}, {'name':1, '_id':0, 'acquisitions':1}).sort('acquisitions.price_amount',1))
# Out:
# []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(datab.find({'founded_year':{'$exists':True}}, {'name':1,'founded_year':1, '_id':0}).sort('founded_year',-1))
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013},
#  {'name': 'Gimigo', 'founded_year': 2013},
#  {'name': 'SEOGroup', 'founded_year': 2013},
#  {'name': 'PeekYou', 'founded_year': 2012},
#  {'name': 'headr', 'founded_year': 2012},
#  {'name': 'Pinger', 'founded_year': 2012},
#  {'name': 'Widgetbox', 'founded_year': 2012},
#  {'name': 'Mobiluck', 'founded_year': 2012},
#  {'name': 'Skydeck', 'founded_year': 2012},
#  {'name': 'Simplicant', 'founded_year': 2012},
#  {'name': 'Springleap', 'founded_year': 2012},
#  {'name': 'Jumbuck Entertainment', 'founded_year': 2012},
#  {'name': 'Carfeine', 'founded_year': 2012},
#  {'name': 'Bling Easy', 'founded_year': 2012},
#  {'name': 'FoodCare', 'founded_year': 2012},
#  {'name': 'Non-Member Films', 'founded_year': 2012},
#  {'name': 'Mokitown', 'founded_year': 2011},
# ...

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
list(datab.find({'founded_day':{'$lte':7}}, {'name':1,'founded_day':1 ,'_id':0}).sort('acquisitions.price_amount',-1).limit(10))
# Out:
# [{'name': 'Google', 'founded_day': 7},
#  {'name': 'Microsoft', 'founded_day': 4},
#  {'name': 'Yahoo!', 'founded_day': 1},
#  {'name': 'Juniper Networks', 'founded_day': 6},
#  {'name': 'FlowPlay', 'founded_day': 1},
#  {'name': 'eBay', 'founded_day': 1},
#  {'name': 'IAC', 'founded_day': 1},
#  {'name': 'Facebook', 'founded_day': 1},
#  {'name': 'PayPal', 'founded_day': 1},
#  {'name': 'Fox Interactive Media', 'founded_day': 1}]

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
list(datab.find({'$and':[{'category_code':'web'},{'number_of_employees':{'$gt': 4000}} ]},{'number_of_employees':1, 'name':1,'category_code':1, '_id': 0}).sort('number_of_employees',1))
# Out:
# [{'name': 'Expedia', 'category_code': 'web', 'number_of_employees': 4400},
#  {'name': 'AOL', 'category_code': 'web', 'number_of_employees': 8000},
#  {'name': 'Webkinz', 'category_code': 'web', 'number_of_employees': 8657},
#  {'name': 'Rakuten', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Los Angeles Times Media Group',
#   'category_code': 'web',
#   'number_of_employees': 10000},
#  {'name': 'Yahoo!', 'category_code': 'web', 'number_of_employees': 13600},
#  {'name': 'eBay', 'category_code': 'web', 'number_of_employees': 15000},
#  {'name': 'Experian', 'category_code': 'web', 'number_of_employees': 15500}]

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
list(datab.find({'$and':[{'acquisitions.price_amount':{'$gt':10000}}, {'acquisitions.price_currency_code':'EUR'}]},{'name':1,'_id': 0}))
# Out:
# [{'name': 'Yahoo!'},
#  {'name': 'Conduit'},
#  {'name': 'FlowPlay'},
#  {'name': 'Nokia'},
#  {'name': 'Toluna'},
#  {'name': 'SAP'},
#  {'name': 'Vodafone'},
#  {'name': 'EXFO'},
#  {'name': 'Meetic'},
#  {'name': 'ACM Tech'},
#  {'name': 'OCLC'}]

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(datab.find({'acquisitions.acquired_month':{'$lt':3}}, {'name':1,'_id':0}).limit(10))
# Out:
# [{'name': 'Facebook'},
#  {'name': 'Twitter'},
#  {'name': 'eBay'},
#  {'name': 'CBS'},
#  {'name': 'Cisco'},
#  {'name': 'Yahoo!'},
#  {'name': 'OpenX'},
#  {'name': 'Google'},
#  {'name': 'Skype'},
#  {'name': 'Intel'}]

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
list(datab.find({'$and': [{'founded_year':{'$gt': 2000}}, {'founded_year':{'$lt': 2010}}, {'acquisitions.acquired_year':{'$lt':2011}}]}, {'name':1, 'founded_year':1,'acquisitions.acquired_year':1,'_id': 0}))
# Out:
# [{'name': 'Digg',
#   'founded_year': 2004,
#   'acquisitions': [{'acquired_year': 2009}]},
#  {'name': 'Facebook',
#   'founded_year': 2004,
#   'acquisitions': [{'acquired_year': 2007},
#    {'acquired_year': 2009},
#    {'acquired_year': 2010},
#    {'acquired_year': 2010},
#    {'acquired_year': 2010},
#    {'acquired_year': 2010},
#    {'acquired_year': 2010},
#    {'acquired_year': 2010},
#    {'acquired_year': 2010},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2012},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2011},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
#    {'acquired_year': 2012},
# ...
