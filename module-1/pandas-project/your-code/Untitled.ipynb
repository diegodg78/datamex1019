# %%
import pandas as pd
import warnings 
warnings.filterwarnings(action='ignore')

# %%
tabla = pd.read_csv("attacks.csv", encoding ="latin1")
tabla.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
tabla.shape
# Out:
# (25723, 24)

# %%
tabla.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
tabla_clean = tabla.drop(columns= ['Unnamed: 22', 'Unnamed: 23','href formula'])
total_rows=tabla_clean.pdf.shape[0]
total_rows
# Out:
# 25723

# %%
tabla_clean[['Date', 'Location', 'Name']].head()
# Out:
#           Date                        Location             Name
# 0  25-Jun-2018     Oceanside, San Diego County      Julie Wolfe
# 1  18-Jun-2018  St. Simon Island, Glynn County  Adyson McNeely
# 2  09-Jun-2018                    Habush, Oahu      John Denges
# 3  08-Jun-2018              Arrawarra Headland             male
# 4  04-Jun-2018                        La Ticla   Gustavo Ramos

# %%
tabla_clean.Year.value_counts(sort='ascending')
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1753.0      1
# 77.0        1
# 1785.0      1
# 1580.0      1
# 1543.0      1
# Name: Year, Length: 249, dtype: int64

# %%
print (tabla.columns.shape)
print (tabla_clean.columns.shape)
print (type(tabla_clean.columns.shape))
# Out:
# (24,)
# (21,)
# <class 'tuple'>

# %%
null_cols=tabla_clean.isnull().sum()
null_cols[null_cols>0]
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# dtype: int64

# %%
bad_index=list(tabla_clean.Injury[tabla_clean.Injury.isnull()].index)
bad_index[0:20]
# Out:
# [1270,
#  1366,
#  2250,
#  2267,
#  2648,
#  3038,
#  3207,
#  3298,
#  3434,
#  3457,
#  3491,
#  3712,
#  3838,
#  3841,
#  4060,
#  4517,
#  4976,
#  5370,
#  5547,
#  5965]

# %%
tabla_clean.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href', 'Case Number.1',
#        'Case Number.2', 'original order'],
#       dtype='object')

# %%
lcol = tabla_clean.rename(columns={'Sex ': 'Sex', 'Case Number.1': 'Case 1', 'Case Number.2': 'Case 2', 'Investigator or Source': 'Source', 'href': 'Link'})

# %%
lcol.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Source', 'pdf', 'Link', 'Case 1', 'Case 2',
#        'original order'],
#       dtype='object')

# %%
lcol.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                    Habush, Oahu      Surfing      John Denges   M  ...
# 3              Arrawarra Headland      Surfing             male   M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos    M  ...
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
print(lcol.isnull())
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
tabla_clean = tabla_clean.fillna('no info') 
tabla_clean
# Out:
#       Case Number         Date     Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018     2018     Boating        USA
# 1      2018.06.18  18-Jun-2018     2018  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018     2018     Invalid        USA
# 3      2018.06.08  08-Jun-2018     2018  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018     2018    Provoked     MEXICO
# ...           ...          ...      ...         ...        ...
# 25718     no info      no info  no info     no info    no info
# 25719     no info      no info  no info     no info    no info
# 25720     no info      no info  no info     no info    no info
# 25721     no info      no info  no info     no info    no info
# 25722          xx      no info  no info     no info    no info
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...
